# %%
import awkward as ak
import numpy as np
import time
import coffea
import uproot
import hist
import vector
print("awkward version ", ak.__version__)
print("coffea version ", coffea.__version__)
from coffea import util, processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema, BaseSchema
from collections import defaultdict
import pickle
# Out:
# awkward version  1.10.1
# coffea version  0.7.19

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## If you want to run from here, do so, otherwise run from command line and comment the next two cells out

# %%
from dijetSelection import *
from dijetSelection_run import *
# Out:
# 0.7.19

# %%
main(testing=True)
# Out:
# Processing files
# UL16NanoAOD
# /mnt/data/cms/store/mc/RunIISummer20UL16NanoAODv9/QCD_Pt-15to7000_TuneCP5_Flat2018_13TeV_pythia8/NANOAODSIM/106X_mcRun2_asymptotic_v17-v1/280000/85CB98E1-D675-984E-BA09-DD7C95483ADF.root
# /mnt/data/cms/store/mc/RunIISummer20UL16NanoAODv9/QCD_Pt-15to7000_TuneCP5_Flat2018_13TeV_pythia8/NANOAODSIM/106X_mcRun2_asymptotic_v17-v1/280000/243023B4-EA5E-8F4B-9ED6-10A813A89A6F.root
# UL16NanoAODAPV
# /mnt/data/cms/store/mc/RunIISummer20UL16NanoAODAPVv9/QCD_Pt-15to7000_TuneCP5_Flat2018_13TeV_pythia8/NANOAODSIM/106X_mcRun2_asymptotic_preVFP_v11-v1/280000/1C3CF9B4-FFAB-2148-81E6-AEA790FDED5F.root
# /mnt/data/cms/store/mc/RunIISummer20UL16NanoAODAPVv9/QCD_Pt-15to7000_TuneCP5_Flat2018_13TeV_pythia8/NANOAODSIM/106X_mcRun2_asymptotic_preVFP_v11-v1/280000/F199A170-9A6F-B14A-9022-75E9761FE8F2.root
# UL17NanoAOD
# ...

# %% [markdown]
# ## Load the pickle file

# %%
with open("jetmass_dijets.pkl", "rb") as f:
    output = pickle.load( f )

# %% [markdown]
# ## Inspect output

# %%
import matplotlib.pyplot as plt

# %%
output
# Out:
# {'pt1': Hist(
#    StrCategory(['UL18NanoAOD', 'UL17NanoAOD', 'UL16NanoAODAPV', 'UL16NanoAOD'], growth=True, name='dataset', label='Primary dataset'),
#    Regular(150, 0, 1500, name='pt', label='$p_{T}$ [GeV]'),
#    storage=Weight()) # Sum: WeightedSum(value=11137, variance=11137) (WeightedSum(value=20517, variance=20517) with flow),
#  'pt2': Hist(
#    StrCategory(['UL18NanoAOD', 'UL17NanoAOD', 'UL16NanoAODAPV', 'UL16NanoAOD'], growth=True, name='dataset', label='Primary dataset'),
#    Regular(150, 0, 1500, name='pt', label='$p_{T}$ [GeV]'),
#    storage=Weight()) # Sum: WeightedSum(value=11847, variance=11847) (WeightedSum(value=20517, variance=20517) with flow),
#  'cutflow': defaultdict(int, {}),
#  'asym': Hist(
#    StrCategory(['UL18NanoAOD', 'UL17NanoAOD', 'UL16NanoAODAPV', 'UL16NanoAOD'], growth=True, name='dataset', label='Primary dataset'),
#    Regular(150, 0, 1, name='asym', label='$p_{T}$_asym'),
# ...

# %% [markdown]
# ## Make plots

# %%
output['pt1'].stack("dataset").project("pt").plot(density=True)
plt.legend()
plt.show()

# %%
output['pt2'].stack("dataset").project("pt").plot(density=True)
plt.legend()
plt.show()

# %%
output['asym'].stack("dataset").project("asym").plot(density=True)
plt.legend()
plt.show()

# %%
output['dphi'].stack("dataset").project("dphi").plot(density=True)
plt.legend()
plt.show()
